# %%
import os 
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

# %%
times = [0]*12
#print(len(times))
#thrs = []
for thr in range(len(times)):#glob.glob("res_have_task_block_10000/*"):
    #print(file)
    file = os.path.join("res_have_task_block_10000", "thr_{}".format(thr+1))
    time = float(open(file,"r").readline().split()[1])
    #times.append(time)
    #thr = int(os.path.basename(file).split("_")[1])
    print("{} {}".format(thr, time))
    #thrs.append(thr)
    times[thr] = time
# Out:
# 0 125.532
# 1 96.4515
# 2 106.322
# 3 99.1669
# 4 96.907
# 5 97.002
# 6 92.3363
# 7 90.3923
# 8 93.0594
# 9 90.9365
# 10 92.1885
# 11 95.3563

# %%
plt.plot(range(1,len(times)+1), times)
plt.xlabel("количество потоков")
plt.ylabel("время(с)")
plt.show()
